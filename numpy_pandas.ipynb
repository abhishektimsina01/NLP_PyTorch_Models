# %%
import numpy as np
import torch

# %% [markdown]
# # Tensors in python:
# ### Tensors are the multi dimenstional matrix

# %%
scalar_tensor = torch.tensor(18)

# %%
print(scalar_tensor)
# Out:
# tensor(18)

# %%
vector_tensor = torch.tensor([1,2,3])
vector_tensor
# Out:
# tensor([1, 2, 3])

# %%
matrix_tensor = torch.tensor([[1,2,3], [4,5,6]])
matrix_tensor
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
tensor = torch.tensor([[[1,2,3], [1,2,3]], [[4,5,6], [4,5,6]]])
tensor
# Out:
# tensor([[[1, 2, 3],
#          [1, 2, 3]],
#
#         [[4, 5, 6],
#          [4, 5, 6]]])
